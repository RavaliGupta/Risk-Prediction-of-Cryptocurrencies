# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_style('whitegrid')

# %%
from pandas_datareader import DataReader

from datetime import datetime

# %%
curr_list = {'btc':'BTC-USD','ripple':'XRP-USD','ethereum':'ETH-USD','bitcash':'BCH-USD'}

# %%
end = datetime.now()
start = datetime(end.year-1,end.month,end.day)


for key,value in curr_list.items():
    
    
    
    globals()[key] = DataReader(value,'yahoo',start,end)

# %%
btc.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count    366.000000    366.000000    366.000000    366.000000    366.000000
# mean    4121.792904   4312.544967   3934.350854   4165.416137   4165.416137
# std     4124.463632   4370.700875   3854.332765   4176.825355   4176.825355
# min      785.429993    826.429993    739.549988    785.429993    785.429993
# 25%     1208.164978   1231.042450   1179.597504   1213.197510   1213.197510
# 50%     2617.070068   2727.239991   2525.214966   2622.590087   2622.590087
# 75%     4617.262451   4753.747314   4492.847656   4631.377564   4631.377564
# max    19346.599609  19870.619141  18750.910156  19345.490234  19345.490234
#
#              Volume
# count  3.660000e+02
# mean   5.236745e+08
# std    7.616796e+08
# min    1.021437e+07
# 25%    8.414473e+07
# 50%    2.610608e+08
# 75%    5.672071e+08
# max    6.245732e+09

# %%
btc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 366 entries, 2017-01-05 to 2018-01-05
# Data columns (total 6 columns):
# Open         366 non-null float64
# High         366 non-null float64
# Low          366 non-null float64
# Close        366 non-null float64
# Adj Close    366 non-null float64
# Volume       366 non-null int64
# dtypes: float64(5), int64(1)
# memory usage: 20.0 KB

# %%
ripple.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  366.000000  366.000000  366.000000  366.000000  366.000000
# mean     0.221339    0.244610    0.204592    0.227897    0.227897
# std      0.339496    0.399047    0.308114    0.358066    0.358066
# min      0.005390    0.005580    0.003000    0.005390    0.005390
# 25%      0.031533    0.033875    0.028370    0.031703    0.031703
# 50%      0.195800    0.203000    0.182400    0.196200    0.196200
# 75%      0.243600    0.253625    0.230875    0.244700    0.244700
# max      2.730000    3.290000    2.580000    2.730000    2.730000
#
#              Volume
# count  3.660000e+02
# mean   4.604869e+07
# std    1.667736e+08
# min    2.028000e+03
# 25%    9.931745e+05
# 50%    7.612270e+06
# 75%    1.946190e+07
# max    1.565229e+09

# %%
ripple.head()
# Out:
#                 Open      High       Low     Close  Adj Close  Volume
# Date
# 2017-01-05  0.006410  0.006889  0.005650  0.006276   0.006276   59727
# 2017-01-06  0.006276  0.006497  0.005995  0.006222   0.006222   20860
# 2017-01-07  0.006222  0.006457  0.006050  0.006363   0.006363    6726
# 2017-01-08  0.006363  0.006457  0.006240  0.006251   0.006251    5847
# 2017-01-09  0.006251  0.006339  0.006124  0.006176   0.006176    4510

# %%
ethereum.head()
# Out:
#              Open   High    Low  Close  Adj Close   Volume
# Date
# 2017-01-05  10.88  11.63   9.07  10.20      10.20  9120265
# 2017-01-06  10.20  10.42   9.44  10.07      10.07  3477359
# 2017-01-07  10.07  10.12   9.47   9.78       9.78  1942619
# 2017-01-08   9.78  10.39   9.67  10.27      10.27  1933043
# 2017-01-09  10.27  10.75  10.03  10.20      10.20  2324307

# %%
bitcash.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-07-31  421.000000  488.799988  218.389999  439.269989  439.269989
# 2017-08-01  439.269989  974.710022  362.019989  551.590027  551.590027
# 2017-08-02  551.590027  635.729980  381.079987  405.920013  405.920013
# 2017-08-03  405.920013  414.380005  252.570007  253.130005  253.130005
# 2017-08-04  253.130005  294.839996  206.639999  220.300003  220.300003
#
#               Volume
# Date
# 2017-07-31   1364069
# 2017-08-01  44939867
# 2017-08-02  39430900
# 2017-08-03  39012988
# 2017-08-04  26697590

# %% [markdown]
# What was the change in price of the stock over time?
#
# Let us view the historical view of the closing price of the stocks

# %%
btc['Adj Close'].plot(figsize=(15,8),legend=True)

# %%
bitcash['Adj Close'].plot(figsize=(15,8),legend=True)

# %%
ripple['Adj Close'].plot(figsize=(15,8),legend=True)

# %%
ethereum['Adj Close'].plot(figsize=(15,8),legend=True)

# %% [markdown]
# Now, let us view the total volume of the stock being traded each day. Volume means # of shares that changed hands during a given day.

# %%
btc['Volume'].plot(figsize=(15,8),legend=True)

# %%
bitcash['Volume'].plot(figsize=(15,8),legend=True)

# %%
ethereum['Volume'].plot(figsize=(15,8),legend=True)

# %%
ripple['Volume'].plot(figsize=(15,8),legend=True)

# %% [markdown]
# What was the moving average of the various stocks?
#
# Let us now calculate Moving averages of the stocks.
#
# Moving Averages:
#
# It helps smooth outprice action by filtering out the noise from the random price fluctuations. It is a trend-following, or lagging, indicator because it is based on past prices.
#
# Two commonly used types:
#
# Simple moving averages: the simple average of a security over a defined number of time periods
#
# exponential moving average: gives greater weight to more recent prices.
#
# The most common applications of moving averages are to identify the trend direction and to determine support and resistance levels.

# %%
ma_day = [10,20,50]

for ma in ma_day:
    
    column_name = 'MA for %s days' %(str(ma))
    btc[column_name] = pd.rolling_mean(btc['Adj Close'],ma)
    bitcash[column_name] = pd.rolling_mean(bitcash['Adj Close'],ma)
    ripple[column_name] = pd.rolling_mean(ripple['Adj Close'],ma)
    ethereum[column_name] = pd.rolling_mean(ethereum['Adj Close'],ma)
# Out:
# C:\Users\mamid\Anaconda3\lib\site-packages\ipykernel\__main__.py:6: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(center=False,window=10).mean()
# C:\Users\mamid\Anaconda3\lib\site-packages\ipykernel\__main__.py:7: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(center=False,window=10).mean()
# C:\Users\mamid\Anaconda3\lib\site-packages\ipykernel\__main__.py:8: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(center=False,window=10).mean()
# C:\Users\mamid\Anaconda3\lib\site-packages\ipykernel\__main__.py:9: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(center=False,window=10).mean()
# ...

# %% [markdown]
# Plotting the moving avergaes

# %%
btc[['Adj Close','MA for 10 days','MA for 20 days','MA for 50 days']].plot(figsize=(10,4))

# %%
bitcash[['Adj Close','MA for 10 days','MA for 20 days','MA for 50 days']].plot(figsize=(10,4))

# %%
ripple[['Adj Close','MA for 10 days','MA for 20 days','MA for 50 days']].plot(figsize=(10,4))

# %%
ethereum[['Adj Close','MA for 10 days','MA for 20 days','MA for 50 days']].plot(figsize=(10,4))

# %% [markdown]
#  What was the daily return of the stock on average?
#
#  Analysing the risk of the stock!!
#
#  Daily Returns:
#
#     The daily return measures the change in a stock's price as a percentage of the previous day's closing price. A positive return means the stock has grown in value. while a negative return means it has lost value. A stock with lower positive and negative daily returns is typically less risky than a stock with higher daily returns, which create larger swings in value.

# %%
btc['Daily Return'] = btc['Adj Close'].pct_change()

btc['Daily Return'].plot(figsize=(15,6),legend=True,linestyle='--',marker='o')

# %%
bitcash['Daily Return'] = bitcash['Adj Close'].pct_change()

bitcash['Daily Return'].plot(figsize=(15,6),legend=True,linestyle='--',marker='o')

# %%
ripple['Daily Return'] = ripple['Adj Close'].pct_change()

ripple['Daily Return'].plot(figsize=(15,6),legend=True,linestyle='--',marker='o')

# %%
ethereum['Daily Return'] = ethereum['Adj Close'].pct_change()

ethereum['Daily Return'].plot(figsize=(15,6),legend=True,linestyle='--',marker='o')

# %% [markdown]
# From the above four cryptocurrencies, ethereum has the highest positive and negative daily returns which indicate that these are a bit risky compared to the others.

# %%
sns.distplot(btc['Daily Return'].dropna(),bins=100)

# %%
sns.distplot(bitcash['Daily Return'].dropna(),bins=100)

# %% [markdown]
# Analysing the returns of all the stocks.

# %%
currencies_df = DataFrame(btc['Adj Close'])

# %%
currencies_df.rename(columns={"Adj Close":"btc"},inplace=True)

# %%
currencies_df['bitcash'] = DataFrame(bitcash['Adj Close'])

# %%
currencies_df['ripple'] = DataFrame(ripple['Adj Close'])

# %%
currencies_df['ethereum'] = DataFrame(ethereum['Adj Close'])

# %%
currencies_df
# Out:
#                      btc      bitcash    ripple    ethereum
# Date
# 2017-01-05    989.349976          NaN  0.006276   10.200000
# 2017-01-06    886.159973          NaN  0.006222   10.070000
# 2017-01-07    888.869995          NaN  0.006363    9.780000
# 2017-01-08    900.859985          NaN  0.006251   10.270000
# 2017-01-09    899.780029          NaN  0.006176   10.200000
# 2017-01-10    904.369995          NaN  0.006815   10.550000
# 2017-01-11    785.429993          NaN  0.006543    9.830000
# 2017-01-12    810.109985          NaN  0.006359    9.810000
# 2017-01-13    824.830017          NaN  0.006669    9.780000
# 2017-01-14    819.630005          NaN  0.006795    9.780000
# 2017-01-15    821.169983          NaN  0.006810    9.880000
# 2017-01-16    827.340027          NaN  0.006780    9.590000
# 2017-01-17    899.659973          NaN  0.006830   10.140000
# 2017-01-18    872.030029          NaN  0.006800   10.190000
# 2017-01-19    895.210022          NaN  0.006840   10.430000
# ...

# %%
## Calculating the daily returns of the closing returns
currencies_rets = currencies_df.dropna().pct_change()

# %%
currencies_rets.head()
# Out:
#                  btc   bitcash    ripple  ethereum
# Date
# 2017-07-31       NaN       NaN       NaN       NaN
# 2017-08-01 -0.009632  0.255697 -0.037725 -0.034440
# 2017-08-02  0.032883 -0.264091  0.022820  0.028746
# 2017-08-03  0.024377 -0.376404 -0.002288 -0.016890
# 2017-08-04  0.133511 -0.129696  0.059633  0.147280

# %%
sns.pairplot(currencies_rets.dropna())

# %% [markdown]
# Different methods of correlations:
#
# spearman correlation increases monotonically  because this is computed based on the ranks and monotonic relationships.
#
# pearson correlation increases linearly and is based on the true values.
#
# kendall's tau is based on the difference between the probability that the two variables are in the same order in the observed data versus the probability that the two variables are in different orders.

# %%
corr = currencies_rets.corr(method='kendall')

# %%
sns.heatmap(corr,annot=True)

# %%
corr = currencies_rets.corr(method='pearson')
sns.heatmap(corr,annot=True,)

# %%
corr = currencies_rets.corr(method='spearman')
sns.heatmap(corr,annot=True,)

# %% [markdown]
# From the above graph we do not see ant strong correlation between the cryptocurrencies.
#
# Risk Analysis:
#
#    Basic way of analysisng risk is to use the information we have gathered on daily percentage returns is by comparing the expected retrun with the standard deviation of the daily returns.

# %%
returns = currencies_rets.dropna()

area = np.pi*20

plt.scatter(returns.mean(),returns.std(),alpha=0.5,s=area)

plt.xlabel('Expected returns')
plt.ylabel('Risk')


for label,x,y in zip(returns.columns,returns.mean(),returns.std()):
    plt.annotate(label,
                xy = (x,y),xytext = (30,30),
                 textcoords = 'offset points', ha = 'right', va = 'bottom',
                arrowprops = dict(arrowstyle = '-', connectionstyle = 'arc3,rad=-0.3')
                
                )

# %% [markdown]
# From the above we can see that the expected returns are high for bitcash and ripple compared to ethereum and btc but the risk is also high for bitchash and ripple.
#
# Analysing the value at risk:
#  This is used to determine the potential for loss in the entity being assessed as well as the probability of occurrence for the defined loss.
#
# How to measure VaR:
#   Assessing the amount of potential loss, the probability of occurrence for the amount of loss and the time frame.
#
# We can treat value at risk as the amount of money we could expect to lose for a given confidence interval.
#
# Value at risk using bootstrap method:
#     Calculating the empirical quantiles from the histogram of daily returns.

# %%
sns.distplot(btc['Daily Return'].dropna(),bins=100)

# %%
returns['btc'].quantile(0.05)
# Out:
# -0.07113820682794009

# %% [markdown]
# The 0.05 empirical quantile of daily returns is at -0.071. That means that with 95% confidence, our worst daily loss will not exceed 7.1%. So if we invest 1 million dollar, our one-day 5% Value at Risk is 0.071 * 1,000,000 = 71,000

# %%
returns['bitcash'].quantile(0.05)
# Out:
# -0.15004027111948143

# %% [markdown]
# One day 5% value at risk is 0.15 * 1,000,000 = 150,000

# %%
returns['ripple'].quantile(0.05)
# Out:
# -0.1076201773710671

# %% [markdown]
# One day 5% value at risk is 0.106 * 1,000,000 = 106,000

# %%
returns['ethereum'].quantile(0.05)
# Out:
# -0.0724436607482151

# %% [markdown]
# One day 5% value at risk is 0.07 * 1,000,000 = 70,000
#
# As seen in the graph of risk, the loss is relatively high for bitcash and ripple.
#
# Value at Risk using the Monte Carlo method:

# %%
days = 365

delta = 1/365

mu = returns.mean()['btc']

sigma = returns.std()['btc']

# %%
def currency_monte_carlo(start_price,days,mu,sigma):
    
    # Define a price array
    price = np.zeros(days)
    price[0] = start_price
    # Schok and Drift
    shock = np.zeros(days)
    drift = np.zeros(days)
    
    # Run price array for number of days
    for x in range(1,days):
        
        # Calculate Schock
        shock[x] = np.random.normal(loc=mu * delta, scale=sigma * np.sqrt(delta))
        # Calculate Drift
        drift[x] = mu * delta
        # Calculate Price
        price[x] = price[x-1] + (price[x-1] * (drift[x] + shock[x]))
        
    return price

# %%
btc.head()
# Out:
#                    Open         High         Low       Close   Adj Close  \
# Date
# 2017-01-05  1135.410034  1150.630005  874.530029  989.349976  989.349976
# 2017-01-06   989.349976  1027.420044  852.549988  886.159973  886.159973
# 2017-01-07   886.159973   900.859985  806.659973  888.869995  888.869995
# 2017-01-08   888.869995   936.130005  875.849976  900.859985  900.859985
# 2017-01-09   900.859985   910.469971  870.909973  899.780029  899.780029
#
#                Volume  MA for 10 days  MA for 20 days  MA for 50 days  \
# Date
# 2017-01-05  244839289             NaN             NaN             NaN
# 2017-01-06  179160668             NaN             NaN             NaN
# 2017-01-07  113037531             NaN             NaN             NaN
# 2017-01-08   70298340             NaN             NaN             NaN
# 2017-01-09   55963281             NaN             NaN             NaN
#
#             Daily Return
# Date
# 2017-01-05           NaN
# 2017-01-06     -0.104301
# ...

# %%
# starting opening price of bitcoin
start_price = btc['Open'].iloc[0]

for run in range(1000):
    plt.plot(currency_monte_carlo(start_price,days,mu,sigma))
plt.xlabel("Days")
plt.ylabel("Price")  
plt.title('Monte Carlo Analysis for Bitcoin')

# %%
runs = 1000

# Create an empty matrix to hold the end price data
simulations = np.zeros(runs)

# Set the print options of numpy to only display 0-5 points from an array to suppress output
np.set_printoptions(threshold=5)

for run in range(runs):    
    # Set the simulation data point as the last stock price for that run
    simulations[run] = currency_monte_carlo(start_price,days,mu,sigma)[days-1];

# %%
# Now we'lll define q as the 1% empirical qunatile, this basically means that 99% of the values should fall between here
q = np.percentile(simulations, 5)
    
# Now let's plot the distribution of the end prices
plt.hist(simulations,bins=200)

# Using plt.figtext to fill in some additional information onto the plot

# Starting Price
plt.figtext(0.6, 0.8, s="Start price: $%.2f" %start_price)
# Mean ending price
plt.figtext(0.6, 0.7, "Mean final price: $%.2f" % simulations.mean())

# Variance of the price (within 99% confidence interval)
plt.figtext(0.6, 0.6, "VaR(0.95): $%.2f" % (start_price - q,))

# Display 1% quantile
plt.figtext(0.15, 0.6, "q(0.95): $%.2f" % q)

# Plot a line at the 1% quantile result
plt.axvline(x=q, linewidth=4, color='r')

# Title
plt.title(u"Final price distribution for Bitcoin currency after %s days" % days, weight='bold');

# %% [raw]
# Awesome! Now we have looked at the 5% empirical quantile of the final price distribution to estimate the Value at Risk for the Bitcoin currency, which looks to be $75.62 for every investment of 1135.41 (the price of one inital bitcoin).
#
# This basically means for every initial currency you purchase your putting about $75.62 at risk 95% of the time from our Monte Carlo Simulation.
#
# In simple terms:
# 1 bitcoin currency initially = $1135.41
# risk for one bitcoin= $75.62
#
#
# what if I had invested $1,000,000 then I have $$1,000,000/$1135.41 = 880.7 bitcoins
#
# then risk for 880.7 coins = $75.62 * 880.7 = $66,598.534 (bootstrap  prediction value= $71,000)

# %%
mu = returns.mean()['ripple']

sigma = returns.std()['ripple']

# %%
# starting opening price of ripple
start_price = ripple['Open'].iloc[0]
#0.006410 
#

for run in range(1000):
    plt.plot(currency_monte_carlo(start_price,days,mu,sigma))
plt.xlabel("Days")
plt.ylabel("Price")  
plt.title('Monte Carlo Analysis for Ripple')

# %%
runs = 10000

# Create an empty matrix to hold the end price data
simulations = np.zeros(runs)

# Set the print options of numpy to only display 0-5 points from an array to suppress output
np.set_printoptions(threshold=5)

for run in range(runs):    
    # Set the simulation data point as the last stock price for that run
    simulations[run] = currency_monte_carlo(start_price,days,mu,sigma)[days-1];

# %%
# Now we'lll define q as the 1% empirical qunatile, this basically means that 99% of the values should fall between here
q = np.percentile(simulations, 1)
    
# Now let's plot the distribution of the end prices
plt.hist(simulations,bins=200)

# Using plt.figtext to fill in some additional information onto the plot

# Starting Price
plt.figtext(0.6, 0.8, s="Start price: $%.2f" %start_price)
# Mean ending price
plt.figtext(0.6, 0.7, "Mean final price: $%.2f" % simulations.mean())

# Variance of the price (within 99% confidence interval)
plt.figtext(0.6, 0.6, "VaR(0.99): $%.2f" % (start_price - q,))

# Display 1% quantile
plt.figtext(0.15, 0.6, "q(0.99): $%.2f" % q)

# Plot a line at the 1% quantile result
plt.axvline(x=q, linewidth=4, color='r')

# Title
plt.title(u"Final price distribution for ripple currency after %s days" % days, weight='bold');

# %% [raw]
# There is not much change in the cost of Ripple cost. Hence there is no risk  for ripple according to the Monte Carlo simulation.

# %%
mu = returns.mean()['bitcash']

sigma = returns.std()['bitcash']

# %%
# starting opening price of ripple
start_price = bitcash['Open'].iloc[0]
#0.006410 
#

for run in range(1000):
    plt.plot(currency_monte_carlo(start_price,days,mu,sigma))
plt.xlabel("Days")
plt.ylabel("Price")  
plt.title('Monte Carlo Analysis for Bitcash')

# %%
runs = 1000

# Create an empty matrix to hold the end price data
simulations = np.zeros(runs)

# Set the print options of numpy to only display 0-5 points from an array to suppress output
np.set_printoptions(threshold=5)

for run in range(runs):    
    # Set the simulation data point as the last stock price for that run
    simulations[run] = currency_monte_carlo(start_price,days,mu,sigma)[days-1];

# %%
# Now we'lll define q as the 1% empirical qunatile, this basically means that 99% of the values should fall between here
q = np.percentile(simulations, 5)
    
# Now let's plot the distribution of the end prices
plt.hist(simulations,bins=200)

# Using plt.figtext to fill in some additional information onto the plot

# Starting Price
plt.figtext(0.6, 0.8, s="Start price: $%.2f" %start_price)
# Mean ending price
plt.figtext(0.6, 0.7, "Mean final price: $%.2f" % simulations.mean())

# Variance of the price (within 99% confidence interval)
plt.figtext(0.6, 0.6, "VaR(0.95): $%.2f" % (start_price - q,))

# Display 1% quantile
plt.figtext(0.15, 0.6, "q(0.95): $%.2f" % q)

# Plot a line at the 1% quantile result
plt.axvline(x=q, linewidth=4, color='r')

# Title
plt.title(u"Final price distribution for bitcash currency after %s days" % days, weight='bold');

# %% [raw]
# one bitcash currency initially = $421
# risk for 1 bitcash is $67.68
#
# what if i had invested $1,000,000 that means i have $1,000,000/$421 = $2375.29 bitcash coins
# risk for 2375.29 coins = $67.68 * 2375.29 =$160,760.09  (bootsrap prediction value = $150,000 )

# %%
mu = returns.mean()['ethereum']

sigma = returns.std()['ethereum']

# %%
# starting opening price of ripple
start_price = ethereum['Open'].iloc[0]


for run in range(1000):
    plt.plot(currency_monte_carlo(start_price,days,mu,sigma))
plt.xlabel("Days")
plt.ylabel("Price")  
plt.title('Monte Carlo Analysis for Ethereum')

# %%
runs = 1000

# Create an empty matrix to hold the end price data
simulations = np.zeros(runs)

# Set the print options of numpy to only display 0-5 points from an array to suppress output
np.set_printoptions(threshold=5)

for run in range(runs):    
    # Set the simulation data point as the last stock price for that run
    simulations[run] = currency_monte_carlo(start_price,days,mu,sigma)[days-1];

# %%
# Now we'lll define q as the 1% empirical qunatile, this basically means that 99% of the values should fall between here
q = np.percentile(simulations, 5)
    
# Now let's plot the distribution of the end prices
plt.hist(simulations,bins=200)

# Using plt.figtext to fill in some additional information onto the plot

# Starting Price
plt.figtext(0.6, 0.8, s="Start price: $%.2f" %start_price)
# Mean ending price
plt.figtext(0.6, 0.7, "Mean final price: $%.2f" % simulations.mean())

# Variance of the price (within 99% confidence interval)
plt.figtext(0.6, 0.6, "VaR(0.95): $%.2f" % (start_price - q,))

# Display 1% quantile
plt.figtext(0.15, 0.6, "q(0.95): $%.2f" % q)

# Plot a line at the 1% quantile result
plt.axvline(x=q, linewidth=4, color='r')

# Title
plt.title(u"Final price distribution for ethereum currency after %s days" % days, weight='bold');

# %% [raw]
# 1 ethereum currency initially = $10.88
#
# risk for 1 ethereum is $0.83
#
# what if i invested $1,000,000 that means i have $1,000,000/$10.88 = $91,911.764 ethereum coins
# risk for 91,911.764 coins = $0.83 * 91,911.764 = $76,286.76   (bootstrap prediction value  = $70,000)
